# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
superstore_df = pd.read_excel('/Users/harshams/Desktop/CIS5357_Assignments/Assignment12/Superstore.xlsx')

# %%
superstore_df
# Out:
#        Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0           1  US-2019-103800 2019-01-03 2019-01-07  Standard Class
# 1           2  US-2019-112326 2019-01-04 2019-01-08  Standard Class
# 2           3  US-2019-112326 2019-01-04 2019-01-08  Standard Class
# 3           4  US-2019-112326 2019-01-04 2019-01-08  Standard Class
# 4           5  US-2019-141817 2019-01-05 2019-01-12  Standard Class
# ...       ...             ...        ...        ...             ...
# 10189   10190  US-2022-143259 2022-12-30 2023-01-03  Standard Class
# 10190   10191  US-2022-115427 2022-12-30 2023-01-03  Standard Class
# 10191   10192  US-2022-156720 2022-12-30 2023-01-03  Standard Class
# 10192   10193  US-2022-143259 2022-12-30 2023-01-03  Standard Class
# 10193   10194  CA-2022-143500 2022-12-30 2023-01-03  Standard Class
#
#       Customer ID      Customer Name      Segment Country/Region  \
# 0        DP-13000      Darren Powers     Consumer  United States
# ...

# %%
superstore_df.shape
# Out:
# (10194, 21)

# %%
superstore_df.isnull().sum(axis=0)
# Out:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# Country/Region    0
# City              0
# State/Province    0
# Postal Code       0
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# Quantity          0
# Discount          0
# Profit            0
# dtype: int64

# %%
superstore_df[superstore_df.isnull().sum(axis=1)==1]
# Out:
# Empty DataFrame
# Columns: [Row ID, Order ID, Order Date, Ship Date, Ship Mode, Customer ID, Customer Name, Segment, Country/Region, City, State/Province, Postal Code, Region, Product ID, Category, Sub-Category, Product Name, Sales, Quantity, Discount, Profit]
# Index: []
#
# [0 rows x 21 columns]

# %%
superstore_df[superstore_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Row ID, Order ID, Order Date, Ship Date, Ship Mode, Customer ID, Customer Name, Segment, Country/Region, City, State/Province, Postal Code, Region, Product ID, Category, Sub-Category, Product Name, Sales, Quantity, Discount, Profit]
# Index: []
#
# [0 rows x 21 columns]

# %%
superstore_df.describe()
# Out:
#              Row ID                     Order Date  \
# count  10194.000000                          10194
# mean    5097.500000  2021-04-29 11:48:25.002942976
# min        1.000000            2019-01-03 00:00:00
# 25%     2549.250000            2020-05-14 00:00:00
# 50%     5097.500000            2021-06-25 00:00:00
# 75%     7645.750000            2022-05-14 00:00:00
# max    10194.000000            2022-12-30 00:00:00
# std     2942.898656                            NaN
#
#                            Ship Date         Sales      Quantity  \
# count                          10194  10194.000000  10194.000000
# mean   2021-05-03 10:52:45.626839296    228.225854      3.791838
# min              2019-01-07 00:00:00      0.444000      1.000000
# 25%              2020-05-19 00:00:00     17.220000      2.000000
# 50%              2021-06-28 00:00:00     53.910000      3.000000
# 75%              2022-05-18 00:00:00    209.500000      5.000000
# ...

# %%
superstore_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10194 entries, 0 to 10193
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          10194 non-null  int64
#  1   Order ID        10194 non-null  object
#  2   Order Date      10194 non-null  datetime64[ns]
#  3   Ship Date       10194 non-null  datetime64[ns]
#  4   Ship Mode       10194 non-null  object
#  5   Customer ID     10194 non-null  object
#  6   Customer Name   10194 non-null  object
#  7   Segment         10194 non-null  object
#  8   Country/Region  10194 non-null  object
#  9   City            10194 non-null  object
#  10  State/Province  10194 non-null  object
#  11  Postal Code     10194 non-null  object
#  12  Region          10194 non-null  object
#  13  Product ID      10194 non-null  object
#  14  Category        10194 non-null  object
#  15  Sub-Category    10194 non-null  object
# ...

# %%
superstore_df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country/Region', 'City',
#        'State/Province', 'Postal Code', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
superstore_df['Region'].unique()
# Out:
# array(['Central', 'East', 'South', 'West'], dtype=object)

# %%
superstore_df['Category'].unique()
# Out:
# array(['Office Supplies', 'Furniture', 'Technology'], dtype=object)

# %%
superstore_df['Sub-Category'].unique()
# Out:
# array(['Paper', 'Binders', 'Labels', 'Storage', 'Art', 'Chairs',
#        'Fasteners', 'Phones', 'Furnishings', 'Accessories', 'Bookcases',
#        'Envelopes', 'Appliances', 'Tables', 'Supplies', 'Machines',
#        'Copiers'], dtype=object)

# %%
superstore_df.groupby(['Region','Category','Sub-Category']).agg({'Profit': ['mean','count','sum']})
# Out:
#                                           Profit
#                                             mean count         sum
# Region  Category        Sub-Category
# Central Furniture       Bookcases     -39.958086    50  -1997.9043
#                         Chairs         42.761944   156   6670.8633
#                         Furnishings   -18.915533   207  -3915.5153
#                         Tables        -49.439589    72  -3559.6504
#         Office Supplies Appliances    -21.452175   123  -2638.6175
# ...                                          ...   ...         ...
# West    Office Supplies Supplies        9.073138    69    626.0465
#         Technology      Accessories    63.893792   258  16484.5983
#                         Copiers       773.089404    25  19327.2351
#                         Machines      -13.212351    41   -541.7064
#                         Phones         32.304627   283   9142.2094
#
# [68 rows x 3 columns]

# %%
superstore_df.groupby(['Region','Category','Sub-Category']).agg({'Profit': ['mean','count','sum']}).reset_index().head(20)
# Out:
#      Region         Category Sub-Category      Profit
#                                                  mean count         sum
# 0   Central        Furniture    Bookcases  -39.958086    50  -1997.9043
# 1   Central        Furniture       Chairs   42.761944   156   6670.8633
# 2   Central        Furniture  Furnishings  -18.915533   207  -3915.5153
# 3   Central        Furniture       Tables  -49.439589    72  -3559.6504
# 4   Central  Office Supplies   Appliances  -21.452175   123  -2638.6175
# 5   Central  Office Supplies          Art    6.790677   176   1195.1591
# 6   Central  Office Supplies      Binders   -2.576089   372   -958.3051
# 7   Central  Office Supplies    Envelopes   30.127598    59   1777.5283
# 8   Central  Office Supplies    Fasteners    4.302156    55    236.6186
# 9   Central  Office Supplies       Labels   14.119466    76   1073.0794
# 10  Central  Office Supplies        Paper   21.719316   321   6971.9005
# ...

# %%
superstore_df.groupby(['Region','Category','Sub-Category']).agg({'Profit': ['mean','count','sum']}).reset_index().sample(10)
# Out:
#      Region         Category Sub-Category     Profit
#                                                 mean count        sum
# 54     West        Furniture       Tables  12.844486   118  1515.6493
# 55     West  Office Supplies   Appliances  59.992337   138  8278.9425
# 37    South        Furniture       Tables -90.648194    51 -4623.0579
# 40    South  Office Supplies      Binders  15.856358   246  3900.6640
# 56     West  Office Supplies          Art   9.419087   256  2411.2862
# 35    South        Furniture       Chairs  75.137378    88  6612.0893
# 45    South  Office Supplies      Storage  17.767941   128  2274.2965
# 11  Central  Office Supplies      Storage   9.314182   212  1974.6065
# 13  Central       Technology  Accessories  39.626397   183  7251.6306
# 5   Central  Office Supplies          Art   6.790677   176  1195.1591

# %%
superstore_df.groupby(['Region','Category','Sub-Category']).agg({'Profit': ['mean','count','sum']}).reset_index().tail(20)
# Out:
#    Region         Category Sub-Category      Profit
#                                                mean count         sum
# 48  South       Technology      Copiers  522.700957     7   3658.9067
# 49  South       Technology     Machines  -79.938500    18  -1438.8930
# 50  South       Technology       Phones   76.909109   140  10767.2753
# 51   West        Furniture    Bookcases  -19.614948    82  -1608.4257
# 52   West        Furniture       Chairs   19.477446   215   4187.6509
# 53   West        Furniture  Furnishings   25.691803   320   8221.3769
# 54   West        Furniture       Tables   12.844486   118   1515.6493
# 55   West  Office Supplies   Appliances   59.992337   138   8278.9425
# 56   West  Office Supplies          Art    9.419087   256   2411.2862
# 57   West  Office Supplies      Binders   34.175800   471  16096.8016
# 58   West  Office Supplies    Envelopes   28.008846    69   1932.6104
# 59   West  Office Supplies    Fasteners   22.081491    74   1634.0303
# ...

# %%
superstore_df.groupby(['Region']).agg({'Profit': ['mean','std']}).plot(kind='bar')
plt.legend(['profit_mean','profit_std'])
plt.ylabel("Profit")           
plt.show()

# %%
superstore_df.groupby('Region').agg({'Profit': ['mean','count','sum']})
# Out:
#             Profit
#               mean count          sum
# Region
# Central  17.072937  2335   39865.3070
# East     31.776042  2986   94883.2603
# South    28.857673  1620   46749.4303
# West     34.060503  3253  110798.8170

# %%
superstore_df.groupby('Region')['Profit'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='Region'>

# %%
superstore_df.groupby(['Region','Category','Sub-Category']).agg({'Profit': ['mean','count','sum']}).reset_index().head(10).plot()
# Out:
# <Axes: >

# %%
superstore_df.groupby(['Region','Category','Sub-Category']).agg({'Profit': ['mean','count','sum']}).reset_index().head(10)
# Out:
#     Region         Category Sub-Category     Profit
#                                                mean count        sum
# 0  Central        Furniture    Bookcases -39.958086    50 -1997.9043
# 1  Central        Furniture       Chairs  42.761944   156  6670.8633
# 2  Central        Furniture  Furnishings -18.915533   207 -3915.5153
# 3  Central        Furniture       Tables -49.439589    72 -3559.6504
# 4  Central  Office Supplies   Appliances -21.452175   123 -2638.6175
# 5  Central  Office Supplies          Art   6.790677   176  1195.1591
# 6  Central  Office Supplies      Binders  -2.576089   372  -958.3051
# 7  Central  Office Supplies    Envelopes  30.127598    59  1777.5283
# 8  Central  Office Supplies    Fasteners   4.302156    55   236.6186
# 9  Central  Office Supplies       Labels  14.119466    76  1073.0794

# %%
region_profit_mean = superstore_df.groupby('Region')['Profit'].mean()

# %%
region_profit_mean.sort_values(ascending = False).plot(kind='bar')
# Out:
# <Axes: xlabel='Region'>

# %%
category_profit_mean = superstore_df.groupby('Category')['Profit'].mean()

# %%
category_profit_mean.sort_values(ascending = False).plot(kind='bar')
# Out:
# <Axes: xlabel='Category'>

# %%
sub_category_profit_mean = superstore_df.groupby('Sub-Category')['Profit'].mean()

# %%
sub_category_profit_mean.sort_values(ascending = False).plot(kind='bar')
# Out:
# <Axes: xlabel='Sub-Category'>

# %%
superstore_df.groupby(['Region','Category','Sub-Category'])['Profit'].mean().reset_index()
# Out:
#      Region         Category Sub-Category      Profit
# 0   Central        Furniture    Bookcases  -39.958086
# 1   Central        Furniture       Chairs   42.761944
# 2   Central        Furniture  Furnishings  -18.915533
# 3   Central        Furniture       Tables  -49.439589
# 4   Central  Office Supplies   Appliances  -21.452175
# ..      ...              ...          ...         ...
# 63     West  Office Supplies     Supplies    9.073138
# 64     West       Technology  Accessories   63.893792
# 65     West       Technology      Copiers  773.089404
# 66     West       Technology     Machines  -13.212351
# 67     West       Technology       Phones   32.304627
#
# [68 rows x 4 columns]

# %%
Average= superstore_df.groupby(['Region','Category','Sub-Category'])['Profit'].mean()

# %%
Average.sort_values(ascending= False).head().plot(x='Region',y='Profit',kind='bar')
# Out:
# <Axes: xlabel='Region,Category,Sub-Category'>

# %%
Average.sort_values(ascending= False).head().plot(x=['Region','Category','Sub-Category'],y='Profit',kind='bar')
# Out:
# <Axes: xlabel='Region,Category,Sub-Category'>

# %%
Average.sort_values(ascending= True).head().plot(x=['Region','Category','Sub-Category'],y='Profit',kind='barh')
# Out:
# <Axes: ylabel='Region,Category,Sub-Category'>

# %%
Average.sort_values(ascending= True).head()
# Out:
# Region   Category    Sub-Category
# East     Furniture   Tables         -130.425260
# South    Furniture   Tables          -90.648194
#          Technology  Machines        -79.938500
# Central  Technology  Machines        -70.765076
#          Furniture   Tables          -49.439589
# Name: Profit, dtype: float64

# %%
superstore_df.groupby('Region').agg({'Profit': ['mean','count','std']}).plot(kind='bar')
plt.legend(['Profit_Mean','Profit_Count','Profit_std'])
plt.title("Profit per Region")
plt.ylabel("Profit")
plt.show()

# %%
superstore_df.groupby('Category').agg({'Profit': ['mean','count','std']}).plot(kind='bar')
plt.legend(['Profit_Mean','Profit_Count','Profit_std'])
plt.title("Profit per Category")
plt.ylabel("Profit")
plt.show()

# %%
superstore_df.groupby('Sub-Category').agg({'Profit': ['mean','count','std']}).plot(kind='bar')
plt.legend(['Profit_Mean','Profit_Count','Profit_std'])
plt.title("Profit per Sub-Category")
plt.ylabel("Profit")
plt.show()
