# %%
import pandas as pd

# %%
df_superstore = pd.read_excel("/Users/harshams/Desktop/CIS5357_Assignments/Assignment9/Superstore.xlsx")

# %%
df_superstore
# Out:
#        Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0           1  US-2019-103800 2019-01-03 2019-01-07  Standard Class
# 1           2  US-2019-112326 2019-01-04 2019-01-08  Standard Class
# 2           3  US-2019-112326 2019-01-04 2019-01-08  Standard Class
# 3           4  US-2019-112326 2019-01-04 2019-01-08  Standard Class
# 4           5  US-2019-141817 2019-01-05 2019-01-12  Standard Class
# ...       ...             ...        ...        ...             ...
# 10189   10190  US-2022-143259 2022-12-30 2023-01-03  Standard Class
# 10190   10191  US-2022-115427 2022-12-30 2023-01-03  Standard Class
# 10191   10192  US-2022-156720 2022-12-30 2023-01-03  Standard Class
# 10192   10193  US-2022-143259 2022-12-30 2023-01-03  Standard Class
# 10193   10194  CA-2022-143500 2022-12-30 2023-01-03  Standard Class
#
#       Customer ID      Customer Name      Segment Country/Region  \
# 0        DP-13000      Darren Powers     Consumer  United States
# ...

# %%
df_superstore.Sales.describe()
# Out:
# count    10194.000000
# mean       228.225854
# std        619.906839
# min          0.444000
# 25%         17.220000
# 50%         53.910000
# 75%        209.500000
# max      22638.480000
# Name: Sales, dtype: float64

# %%
df_superstore.Profit.describe()
# Out:
# count    10194.000000
# mean        28.673417
# std        232.465115
# min      -6599.978000
# 25%          1.760800
# 50%          8.690000
# 75%         29.297925
# max       8399.976000
# Name: Profit, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_superstore[['Sales','Profit']].plot(kind='box')
plt.title("A boxplot of Sales and Profit ")
# Out:
# Text(0.5, 1.0, 'A boxplot of Sales and Profit ')

# %%
sns.boxplot(df_superstore[['Sales','Profit']])
# Out:
# <Axes: >

# %%
((df_superstore.Discount)*100).plot(kind='hist',bins = 30)
plt.title("A histogram of Discount")
plt.xlabel("Discount")
# Out:
# Text(0.5, 0, 'Discount')

# %%
df_superstore.shape
# Out:
# (10194, 21)

# %%
plt.bar(df_superstore.Region,df_superstore.Sales)
plt.plot(df_superstore.Region,df_superstore.Sales,'or')
plt.title("A bar chart with Sales by Region")
plt.xlabel("Regions")
plt.ylabel("Sales")
# Out:
# Text(0, 0.5, 'Sales')

# %%
df_superstore = pd.read_excel("/Users/harshams/Desktop/CIS5357_Assignments/Assignment9/Superstore.xlsx")

# %%
df_superstore
# Out:
#        Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0           1  US-2019-103800 2019-01-03 2019-01-07  Standard Class
# 1           2  US-2019-112326 2019-01-04 2019-01-08  Standard Class
# 2           3  US-2019-112326 2019-01-04 2019-01-08  Standard Class
# 3           4  US-2019-112326 2019-01-04 2019-01-08  Standard Class
# 4           5  US-2019-141817 2019-01-05 2019-01-12  Standard Class
# ...       ...             ...        ...        ...             ...
# 10189   10190  US-2022-143259 2022-12-30 2023-01-03  Standard Class
# 10190   10191  US-2022-115427 2022-12-30 2023-01-03  Standard Class
# 10191   10192  US-2022-156720 2022-12-30 2023-01-03  Standard Class
# 10192   10193  US-2022-143259 2022-12-30 2023-01-03  Standard Class
# 10193   10194  CA-2022-143500 2022-12-30 2023-01-03  Standard Class
#
#       Customer ID      Customer Name      Segment Country/Region  \
# 0        DP-13000      Darren Powers     Consumer  United States
# ...

# %%
df_superstore.at[4,'Customer Name']
# Out:
# 'Mick Brown'

# %%
df_superstore.loc[4,'Customer Name']
# Out:
# 'Mick Brown'

# %%
df_superstore.loc[0:4,'Customer Name']
# Out:
# 0    Darren Powers
# 1    Phillina Ober
# 2    Phillina Ober
# 3    Phillina Ober
# 4       Mick Brown
# Name: Customer Name, dtype: object

# %%
df_superstore.iloc[0:4,6:7]
# Out:
#    Customer Name
# 0  Darren Powers
# 1  Phillina Ober
# 2  Phillina Ober
# 3  Phillina Ober

# %%
df_superstore.loc[:,["Customer ID" , "Customer Name"]]
# Out:
#       Customer ID      Customer Name
# 0        DP-13000      Darren Powers
# 1        PO-19195      Phillina Ober
# 2        PO-19195      Phillina Ober
# 3        PO-19195      Phillina Ober
# 4        MB-18085         Mick Brown
# ...           ...                ...
# 10189    PO-18865  Patrick O'Donnell
# 10190    EB-13975         Erica Bern
# 10191    JM-15580      Jill Matthias
# 10192    PO-18865  Patrick O'Donnell
# 10193    HO-15230        Harry Olson
#
# [10194 rows x 2 columns]

# %%
df_superstore.sort_values('Sales',ascending=False).head(5)
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 226      227  US-2019-145317 2019-03-18 2019-03-23  Standard Class
# 5894    5895  US-2021-118689 2021-10-02 2021-10-09  Standard Class
# 7255    7256  US-2022-140151 2022-03-23 2022-03-25     First Class
# 9171    9172  US-2022-127180 2022-10-22 2022-10-24     First Class
# 9517    9518  US-2022-166709 2022-11-17 2022-11-22  Standard Class
#
#      Customer ID Customer Name      Segment Country/Region           City  \
# 226     SM-20320   Sean Miller  Home Office  United States   Jacksonville
# 5894    TC-20980  Tamara Chand    Corporate  United States      Lafayette
# 7255    RB-19360  Raymond Buch     Consumer  United States        Seattle
# 9171    TA-21385  Tom Ashbrook  Home Office  United States  New York City
# 9517    HL-15040  Hunter Lopez     Consumer  United States         Newark
#
#       ... Postal Code   Region       Product ID    Category Sub-Category  \
# ...

# %%
# Calculating the required statistics
mean = np.mean(df_superstore.Sales)
Q1 = np.percentile(df_superstore.Sales, 25)
Q3 = np.percentile(df_superstore.Sales, 75)
maximum = np.max(df_superstore.Sales)
minimum = np.min(df_superstore.Sales)

# Identifying outliers
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
outliers = [x for x in df_superstore.Sales if x < lower_bound or x > upper_bound]

print(f"Mean: {mean}")
print(f"Q1: {Q1}")
print(f"Q3: {Q3}")
print(f"Max: {maximum}")
print(f"Min: {minimum}")
print(f"Outliers: {outliers}")
# Out:
# Mean: 228.22585386501862
# Q1: 17.22
# Q3: 209.5
# Max: 22638.48
# Min: 0.44399999999999995
# ...

# %%
# Calculating the required statistics
mean = np.mean(df_superstore.Profit)
Q1 = np.percentile(df_superstore.Profit, 25)
Q3 = np.percentile(df_superstore.Profit, 75)
maximum = np.max(df_superstore.Profit)
minimum = np.min(df_superstore.Profit)

# Identifying outliers
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
outliers = [x for x in df_superstore.Profit if x < lower_bound or x > upper_bound]

print(f"Mean: {mean}")
print(f"Q1: {Q1}")
print(f"Q3: {Q3}")
print(f"Max: {maximum}")
print(f"Min: {minimum}")
print(f"Outliers: {outliers}")
# Out:
# Mean: 28.67341716696095
# Q1: 1.7607999999999997
# Q3: 29.297924999999985
# Max: 8399.975999999999
# Min: -6599.978000000001
# ...

# %%
df_superstore.Sales.describe()
# Out:
# count    10194.000000
# mean       228.225854
# std        619.906839
# min          0.444000
# 25%         17.220000
# 50%         53.910000
# 75%        209.500000
# max      22638.480000
# Name: Sales, dtype: float64

# %%
df_superstore.Profit.describe()
# Out:
# count    10194.000000
# mean        28.673417
# std        232.465115
# min      -6599.978000
# 25%          1.760800
# 50%          8.690000
# 75%         29.297925
# max       8399.976000
# Name: Profit, dtype: float64

# %%
#df_superstore.sort_values('Sales',ascending=False).head(5)
df_South = df_superstore.loc[df_superstore.Region == 'South']

# %%
df_South.sort_values('Sales',ascending=False).head(5)
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 226      227  US-2019-145317 2019-03-18 2019-03-23  Standard Class
# 4282    4283  US-2021-158841 2021-02-02 2021-02-04    Second Class
# 9318    9319  US-2022-168116 2022-11-04 2022-11-04        Same Day
# 2242    2243  US-2020-145352 2020-03-16 2020-03-22  Standard Class
# 8422    8423  US-2022-129021 2022-08-23 2022-08-26    Second Class
#
#      Customer ID         Customer Name      Segment Country/Region  \
# 226     SM-20320           Sean Miller  Home Office  United States
# 4282    SE-20110          Sanjit Engle     Consumer  United States
# 9318    GT-14635        Grant Thornton    Corporate  United States
# 2242    CM-12385  Christopher Martinez     Consumer  United States
# 8422    PO-18850       Patrick O'Brill     Consumer  United States
#
#               City  ... Postal Code Region       Product ID         Category  \
# 226   Jacksonville  ...       32216  South  TEC-MA-10002412       Technology
# ...

# %%
df_Central = df_superstore.loc[df_superstore.Region == 'Central']

# %%
df_Central.sort_values('Sales',ascending=False).head(5)
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 5894    5895  US-2021-118689 2021-10-02 2021-10-09  Standard Class
# 6674    6675  US-2021-117121 2021-12-17 2021-12-21  Standard Class
# 1203    1204  US-2019-116904 2019-09-23 2019-09-28  Standard Class
# 1063    1064  US-2019-139892 2019-09-08 2019-09-12  Standard Class
# 6882    6883  US-2022-138289 2022-01-16 2022-01-18    Second Class
#
#      Customer ID  Customer Name    Segment Country/Region         City  ...  \
# 5894    TC-20980   Tamara Chand  Corporate  United States    Lafayette  ...
# 6674    AB-10105  Adrian Barton   Consumer  United States      Detroit  ...
# 1203    SC-20095   Sanjit Chand   Consumer  United States  Minneapolis  ...
# 1063    BM-11140   Becky Martin   Consumer  United States  San Antonio  ...
# 6882    AR-10540    Andy Reiter   Consumer  United States      Jackson  ...
#
#      Postal Code   Region       Product ID         Category Sub-Category  \
# ...

# %%
df_West = df_superstore.loc[df_superstore.Region == 'West']

# %%
df_West.sort_values('Sales',ascending=False).head(5)
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 7255    7256  US-2022-140151 2022-03-23 2022-03-25     First Class
# 811      812  US-2019-143917 2019-07-25 2019-07-27    Second Class
# 9010    9011  CA-2022-131807 2022-10-05 2022-10-10  Standard Class
# 9077    9078  US-2022-135909 2022-10-13 2022-10-20  Standard Class
# 4446    4447  US-2021-136301 2021-03-13 2021-03-15    Second Class
#
#      Customer ID Customer Name    Segment Country/Region           City  ...  \
# 7255    RB-19360  Raymond Buch   Consumer  United States        Seattle  ...
# 811     KL-16645  Ken Lonsdale   Consumer  United States  San Francisco  ...
# 9010    GG-14650  Greg Guthrie  Corporate         Canada        Calgary  ...
# 9077    JW-15220     Jane Waco  Corporate  United States     Sacramento  ...
# 4446    EH-13765  Edward Hooks  Corporate  United States  San Francisco  ...
#
#      Postal Code Region       Product ID         Category Sub-Category  \
# ...

# %%
df_East = df_superstore.loc[df_superstore.Region == 'East']

# %%
df_East.sort_values('Sales',ascending=False).head(5)
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 9171    9172  US-2022-127180 2022-10-22 2022-10-24     First Class
# 9517    9518  US-2022-166709 2022-11-17 2022-11-22  Standard Class
# 4624    4625  US-2021-107440 2021-04-16 2021-04-20  Standard Class
# 4845    4846  US-2021-143714 2021-05-23 2021-05-27  Standard Class
# 1868    1869  US-2019-145541 2019-12-14 2019-12-21  Standard Class
#
#      Customer ID       Customer Name      Segment Country/Region  \
# 9171    TA-21385        Tom Ashbrook  Home Office  United States
# 9517    HL-15040        Hunter Lopez     Consumer  United States
# 4624    BS-11365        Bill Shonely    Corporate  United States
# 4845    CC-12370  Christopher Conant     Consumer  United States
# 1868    TB-21400    Tom Boeckenhauer     Consumer  United States
#
#                City  ... Postal Code Region       Product ID    Category  \
# 9171  New York City  ...       10024   East  TEC-CO-10004722  Technology
# ...

# %%
df_regions = df_superstore.groupby('Region').agg({'Sales': ['sum','max','min','mean']})

# %%
df_regions
# Out:
#                Sales
#                  sum        max    min        mean
# Region
# Central  503170.6728  17499.950  0.444  215.490652
# East     691828.1680  11199.968  0.852  231.690612
# South    391721.9050  22638.480  1.167  241.803645
# West     739813.6085  13999.960  0.990  227.425026

# %%
df_superstore
# Out:
#        Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0           1  US-2019-103800 2019-01-03 2019-01-07  Standard Class
# 1           2  US-2019-112326 2019-01-04 2019-01-08  Standard Class
# 2           3  US-2019-112326 2019-01-04 2019-01-08  Standard Class
# 3           4  US-2019-112326 2019-01-04 2019-01-08  Standard Class
# 4           5  US-2019-141817 2019-01-05 2019-01-12  Standard Class
# ...       ...             ...        ...        ...             ...
# 10189   10190  US-2022-143259 2022-12-30 2023-01-03  Standard Class
# 10190   10191  US-2022-115427 2022-12-30 2023-01-03  Standard Class
# 10191   10192  US-2022-156720 2022-12-30 2023-01-03  Standard Class
# 10192   10193  US-2022-143259 2022-12-30 2023-01-03  Standard Class
# 10193   10194  CA-2022-143500 2022-12-30 2023-01-03  Standard Class
#
#       Customer ID      Customer Name      Segment Country/Region  \
# 0        DP-13000      Darren Powers     Consumer  United States
# ...

# %%
df_new = df_superstore.groupby(['Region','Category'])['Sales'].sum()

# %%
df_new
# Out:
# Region   Category
# Central  Furniture          164537.6518
#          Office Supplies    168216.7090
#          Technology         170416.3120
# East     Furniture          212231.6960
#          Office Supplies    211658.4010
#          Technology         267938.0710
# South    Furniture          117298.6840
#          Office Supplies    125651.3130
#          Technology         148771.9080
# West     Furniture          260679.7295
#          Office Supplies    226366.8910
#          Technology         252766.9880
# Name: Sales, dtype: float64

# %%
df_new.loc[slice(None),slice('Furniture'), :]
# Out:
# Region   Category
# Central  Furniture    164537.6518
# East     Furniture    212231.6960
# South    Furniture    117298.6840
# West     Furniture    260679.7295
# Name: Sales, dtype: float64

# %%
df_new.loc['Central']
# Out:
# Category
# Furniture          164537.6518
# Office Supplies    168216.7090
# Technology         170416.3120
# Name: Sales, dtype: float64

# %%
df_new.loc[['Central','West'],['Furniture','Technology'], : ]
# Out:
# Region   Category
# Central  Furniture     164537.6518
#          Technology    170416.3120
# West     Furniture     260679.7295
#          Technology    252766.9880
# Name: Sales, dtype: float64

# %%
df_new.loc[['West'],['Technology'], :]
# Out:
# Region  Category
# West    Technology    252766.988
# Name: Sales, dtype: float64

# %%
df_superstore.groupby('City')['Profit'].sum()
# Out:
# City
# Aberdeen          6.6300
# Abilene          -3.7584
# Akron          -186.6356
# Albuquerque     634.0881
# Alexandria      318.6183
#                  ...
# Woonsocket       78.6791
# Yonkers        2767.7557
# York           -102.1692
# Yucaipa          13.2080
# Yuma           -465.9909
# Name: Profit, Length: 542, dtype: float64
